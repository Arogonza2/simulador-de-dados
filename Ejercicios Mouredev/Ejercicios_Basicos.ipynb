# %% [markdown]
# Escribe un programa que permita generar la tabla de multiplicar de un numero entero positivo N, comenzando desde 1.
# Si el usuario escribe un numero incorrecto, el programa no se ejecuta.
# En cambio pregunta de nuevo por l ainformacion hasta que el dato ingresado sea correcto

# %%
comprobar = True

while comprobar == True:

    n = int(input("Indique un numero entero positivo:"))

    if n > 0 :
                
        for i in range(1,11):
            
            print(n,"por",i ,"es igual a:", n*i)
            
        comprobar = False
        
    else:
        print(" El numero introducido no es correcto, intentelo de nuevo. ")

# %% [markdown]
# Escribe un programa que, al recibir como dato un numero entero positivo N calcule el resultado de la siguiente serie:
#
# 1 + (1/2) + (1/3) + (1/5), + ..... + (1/N)
#
# Si el usuario escribe un numero incorrecto, el programa no se ejecuta.
# En cambio pregunta de nuevo por la informacion hasta que el dato ingresado sea correcto

# %%
comprobar = True

while comprobar == True:

    n = int(input("Indique un numero entero positivo:"))

    if n > 0 :
        resultado = 0
        
        for i  in range(1,n+1):
            resultado += (1/i)
        print(" El resultado de la serie es: ", resultado)
         
        comprobar = False   
            
    else:
            print(" El numero introducido no es correcto, intentelo de nuevo. ")

# %% [markdown]
# Escribe un programa que, al recibir como dato un numero entero positivo N calcule el resultado de la siguiente serie:
#
# 1 / (1/2) * (1/3) / (1/4), * ..... (*/) (1/N)
#
# Si el usuario escribe un numero incorrecto, el programa no se ejecuta.
# En cambio pregunta de nuevo por la informacion hasta que el dato ingresado sea correcto

# %%
comprobar = True

while comprobar == True:

    n = int(input("Indique un numero entero positivo:"))

    if n > 0 :
        resultado = 1
        
        for i  in range(2,n+1):
            
            if i % 2 == 0:
                resultado= resultado / (1/i)
            else:
                resultado = resultado * (1/i)
                   
        print(" El resultado de la serie es: ", resultado)
         
        comprobar = False   
            
    else:
            print(" El numero introducido no es correcto, intentelo de nuevo. ")

# %% [markdown]
# Crea un programa que, al recibir como datos el peso, la altura y el genero de N personas que pertenecen a un estado de un pais,
# obtenga el promedio del peso y el promedio de la altura, tanto de la poblacion masculina como de la femenina.
#
# Si el usuario escribe un numero incorrecto, el programa no se ejecuta.
# En cambio pregunta de nuevo por la informacion hasta que el dato ingresado sea correcto

# %%
comprobar = True
while comprobar == True:

    n = int(input(" Introduce la cantidad de personas a evaluar: "))

    if n > 0:
        
        comprobar = False
        
        peso_hombres = 0
        altura_hombres = 0
        peso_mujeres = 0
        altura_mujeres = 0
        cantidad_hombres = 0
        cantidad_mujeres = 0
        
        for i in range(n):
            
            peso =float(input("indique el peso en Kg:"))
            altura = int(input("Introduce la altura en Cm"))
           
            comprobar_genero = True
            while comprobar_genero == True:
            
                genero = input(" Introduce el genero de la persona (M,maxculino ) (F,femenino):")
        
                if genero.upper() == "M":
                    peso_hombres += peso
                    altura_hombres += altura
                    cantidad_hombres += 1
                    
                    comprobar_genero = False
                    
                elif genero.upper() == "F":
                    peso_mujeres += peso
                    altura_mujeres += altura
                    cantidad_mujeres += 1
                    
                    comprobar_genero = False
                    
                else:
                    print(" EL genero ointroducido no es correcto. intentalo de nuevo.")
                
            promedio_alturah = 0
            promedio_pesoh = 0
            
            if cantidad_hombres > 0:
                
                promedio_pesoh = cantidad_hombres / peso_hombres 
                promedio_alturah = cantidad_mujeres / altura_hombres
            
            promedio_pesom = 0
            promedio_alturam = 0
        
            if cantidad_mujeres > 0:
                    
                promedio_pesom = cantidad_mujeres / peso_mujeres
                promedio_alturam = cantidad_mujeres / altura_mujeres


            print("\nDe los datos introducidos, los promedios son : "
                "\nPromedio peso de hombres: ",promedio_pesoh,
                "\nPromedio altura hombres : ",promedio_alturah,
                "\nPromedio de peso mujeres: ",promedio_pesom,
                "\nPromedio altura mujeres: ",promedio_alturam)
            
    else:
        print(" El numero ingresado no es correcto, intentalo de nuevo.")

# %% [markdown]
# Crea un programa que, al recibir como dato un numero entero N, obtenga el resultado de la siguiente serie:
#
# 1 - 2 + 3 - .... +- N^N
#
# Si el usuario escribe un numero incorrecto, el programa no se ejecuta.
# En cambio pregunta de nuevo por la informacion hasta que el dato ingresado sea correcto

# %%
resultado = 0
comprobar = True

while comprobar == True:
     
     n = int(input(" Introduce un numero de terminos de la serie: "))

     if n > 0:
          
          comprobar = False
          
          for i in range(1, n+1):
               
               if i % 2 == 0:
                    resultado -= i**i
               else:
                    resultado += i**i
                    
          print(" El resultado de la serie es : ", resultado)
     

     else:
          print(" El numero ingresado no es correcto, intentalo de nuevo.")

# %% [markdown]
# Crea un programa que lea un numero entero positivo N y escriba todos los numeros primos menores a dicho numero.
#
# Si el usuario escribe un numero incorrecto, el programa no se ejecuta.
# En cambio pregunta de nuevo por la informacion hasta que el dato ingresado sea correcto

# %%
comprobar = True

while comprobar:

    n = int(input(" Introduce un numero de terminos de la serie: "))

    if n > 0:
        
        comprobar = False
        
        for i in range(2,n):
            
            creciente = 2
            
            esprimo = True
            
            while esprimo and creciente < i: 
                
                if i  % creciente == 0:
                    
                    esprimo = False 
                    
                else:
                    
                    creciente += 1
        
            if esprimo: 
                
                print(i," Es primo ")
    
    else:
        print(" El numero ingresado no es correcto, intentalo de nuevo.")

# %% [markdown]
# Crea un programa que, al recibir como datos dos numeros enteros positivos y que no sean iguales,
# obtenga e imprima todos los numeros primos gemelos comprendidos entre dichos numeros.
# Los primos gemelos son una pareja de numeros primos con una diferencia entre si de exactamente dos. 3 y 5 son primos gemelos.
#
# Si el usuario escribe un numero incorrecto, el programa no se ejecuta.
# En cambio pregunta de nuevo por la informacion hasta que el dato ingresado sea correcto

# %%
comprobar = True

while comprobar:

    n1 = int(input("Introduce el primer numero entero positivo:"))
    n2 = int(input(" Introduce el segundo numero entero positivo:"))

    a = 0
    if n1 > 0 and n2 > 0 and n1 != n2 :
        
        comprobar = False
        
        if n1 > n2:
            n1 ^= n2
            n2 ^= n1
            n1 ^= n2

        for i in range(n1, n2+1):
            
            creciente = 2  
            esprimo = True
            
            while esprimo and creciente < i:
                
                if i % creciente == 0:
                    esprimo = False
                
                else:
                    creciente += 1 
            
            if esprimo and not a:
                a = i
                
            elif esprimo and a:
                b = i
                
                if b-a == 2:
                    
                    print(a, "y", b, "son primos gemelos" )
                
                a = i
            
    else:
        
        if n1 == n2:
            
            print(" Los numeros son iguales, intentelo de nuevo.")
        
        else:
            print(" Los numeros no son correctos, Intentelo nuevamente.")

# %% [markdown]
# Crea un programa que calcule el maximo comun divisor (MCD de dos numeros naturales N1 y N2.
# El MCD entre dos numeros es el natural mas grande que divide a ambos)
#
# Si el usuario escribe un numero incorrecto, el programa no se ejecuta.
# En cambio pregunta de nuevo por la informacion hasta que el dato ingresado sea correcto

# %%
comprobar = True

while comprobar:
  
     a = int(input(" Introduce el primer numero entero positivo:"))
     b = int(input(" Introduce el segundo numero entero positivo:"))

     MCD = False

     if a > 0 and b > 0 and a != b :
          
          comprobar = False
          
          if a > b :
               aux = a
               a = b
               b = a 
          
          i = a
          
          while not MCD and i >= 1:
          
               if a % i == 0  and b % i == 0:
               
                    print(" El MCD es ", i)
                    MCD = True
               
               else:
                    i -= 1
               
     else:
          
          if a == b:
               print(" Los numeros no pueden ser iguales, intentelo de nuevo")
          
          else:
               
               print(" Los numeros no son correctos, Intentelo de nuevo.")

# %% [markdown]
# Crea un programa que, al recibir como dato un numero entero positivo,
# escriba una figura como la que se muestra a continuacion (ejemplo para N 6)
#
# 1
# 12
# 123
# 1234
# 12345
# 123456
# 12345
# 1234
# 123
# 12
# 1

# %%
comprobar = True
 
while comprobar:
 
    n = int(input("Indique un numero entero positivo:"))

    if n > 0:
        
        comprobar = False
        
        for i in range(1, n+1):
            print(" ")
            
            for j in range(1, i+1):    
                print(j, end=' ')
        
        for i in range(n-1,0,-1):
            print("")
            
            for j in range(1, i+1):
                print(j,end= " ")
        
    else:
        print("El numero introducido no es correcto, intentelo de nuevo.")
