# %%
def steps():
    number = int(input(" Escribe un numero mayor de 1"))  
    
    number_steps = 0  
    
    while number != 1:  
        if number %2 == 0:
            number = number// 2
            print(number)
        
        elif number %2 != 0:
            number = number *3 + 1
            print(number)
        
        number_steps += 1
    
    return number
    
steps()
# Out:
# 9
# 28
# 14
# 7
# 22
# 11
# 34
# 17
# 52
# 26
# 13
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# 1

# %%
def steps(n):
    n = int(input(" Escribe un numero mayor de 1")) 
    if n <= 0:
            raise ValueError(' El numero tiene que ser positivo y mayor de 0')
    n = 0
    while n != 1:
            n = 3 * n +1 if n %2 else n /2
            steps += 1 

    print (n)
