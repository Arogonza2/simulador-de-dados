# %%
# Estructuras de datos


#Listas []

my_list = ["Brais", "Bl4ck","Wolfy", "Visionos" ]
print(my_list)


my_list.append("Castor") # insertar un nombre a la lista 
print(my_list)

my_list[1] = "Cuervillo"
print(my_list)
my_list.remove("Brais") # Borrado un nombre de la lista 
print(my_list)

my_list.sort()   # Ordenacion
print(my_list)
print(type(my_list))





# Tuplas () Son inmutables 

my_tuple : tuple = ('Brais', 'Moure', '@mouredev', '36')
print(my_tuple)  

print(my_tuple [1]) 
print(my_tuple [2])
my_tuple = tuple(sorted(my_tuple)) # Ordenacion
print(my_tuple) 
print(type(my_tuple))


# Sets {} estructura no ordenada y no acepta duplicados no se puede ordenar

my_set = {'Brais', 'Moure', '@mouredev', '36'}
print(my_set)
my_set.add("mouredev@gmail.com")  #Insercion
print(my_set) 
my_set.add("mouredev@gmail.com") 
print(my_set)
my_set.remove("Moure")  #Eliminacion
print(my_set)
my_set = set(sorted(my_set))  #no se puede ordenar
print(my_set)
print(type(my_set))



# Diccionarios {}

my_dict: dict = {
    "name":'Brais',
    "surname":'Moure',
    "alias":'@mouredev',
    "age":'36'
}
my_dict ["name"]  # Acceso
print(my_dict)
my_dict ["email"] = "mouredev@gmail"  # Insertar
my_dict["age"] = "37"           # Actualizacion 
print(my_dict)
del my_dict ["surname"]
print(my_dict)
my_dict = dict(sorted(my_dict.items()))
print(my_dict)
print(type(my_dict))
# Out:
# ['Brais', 'Bl4ck', 'Wolfy', 'Visionos']
# ['Brais', 'Bl4ck', 'Wolfy', 'Visionos', 'Castor']
# ['Brais', 'Cuervillo', 'Wolfy', 'Visionos', 'Castor']
# ['Cuervillo', 'Wolfy', 'Visionos', 'Castor']
# ['Castor', 'Cuervillo', 'Visionos', 'Wolfy']
# <class 'list'>
# ('Brais', 'Moure', '@mouredev', '36')
# Moure
# @mouredev
# ('36', '@mouredev', 'Brais', 'Moure')
# <class 'tuple'>
# {'36', '@mouredev', 'Moure', 'Brais'}
# {'mouredev@gmail.com', '36', 'Brais', '@mouredev', 'Moure'}
# {'mouredev@gmail.com', '36', 'Brais', '@mouredev', 'Moure'}
# {'mouredev@gmail.com', '36', 'Brais', '@mouredev'}
# {'mouredev@gmail.com', 'Brais', '@mouredev', '36'}
# <class 'set'>
# {'name': 'Brais', 'surname': 'Moure', 'alias': '@mouredev', 'age': '36'}
# {'name': 'Brais', 'surname': 'Moure', 'alias': '@mouredev', 'age': '37', 'email': 'mouredev@gmail'}
# {'name': 'Brais', 'alias': '@mouredev', 'age': '37', 'email': 'mouredev@gmail'}
# ...

# %% [markdown]
# Crea una agenda de contactos por terminal.
#  * - Debes implementar funcionalidades de búsqueda, inserción, actualización
#  *   y eliminación de contactos.
#  * - Cada contacto debe tener un nombre y un número de teléfono.
#  * - El programa solicita en primer lugar cuál es la operación que se quiere realizar,
#  *   y a continuación los datos necesarios para llevarla a cabo.
#  * - El programa no puede dejar introducir números de teléfono no númericos y con más
#  *   de 11 dígitos (o el número de dígitos que quieras).
#  * - También se debe proponer una operación de finalización del programa.

# %%
# Ejercicio Agenda 

def my_agenda():
    
    agenda = {}
    
    def insert_contac():
        phone = input("Introduce el telefono de telefono: ")
        if phone.isdigit() and len(phone) >0 and len(phone) <= 11:
            agenda[name] = phone
        else:
            print("Debes introducir un numero de telefono con menos de 12 digitos")
    
    while True:    
        
     print("")
    print("1. Buscar  contacto")
    print("2. Insertar contacto")
    print("3. Actualizar contacto")
    print("4. Eliminar contacto")
    print("5. Salir")
    
    opcion = input("Selecciona una opcion:")
    
    match option:
        case "1":
            name = input("Introduce el nombre del contacto a buscar: ")
            if name in agenda:
                print(f"El numero de telefono de {name} es {agenda[name]}.")
            else:
                print(f"El contacto {name} no existe.")
                
        case "2":
            name = input("Introduce el nombre del contacto: ")
            
            insert_contac()
            
       
        case "3": 
            name = input("Introduce el nombre del contacto a actualizar: ")
            if name in agenda:
                insert_contac()
            
        case "4":
            name = input("Introduce el nombre del contacto a eliminar: ")
            if name in agenda:
                del agenda[name]
            else: 
                print(f"El contacto {name} no existe.")
        
        case "5":
            print ("Saliendo de la agenda.")
            break
        
        case _:
            print("Opcion no valida. Elige una opcion del 1 al 5.")
        
my_agenda()
# Out:
#   Cell In[2], line 53
#     break
#     ^
# SyntaxError: 'break' outside loop
